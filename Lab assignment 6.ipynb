# %%
#1
class Student:
    id = 0
    def __init__(self,name,department,age,cgpa):
        self.name = name
        self.department = department
        self.age = age
        self.cgpa = cgpa
        Student.id+=1
        
    def get_details(self):
        print("ID:",Student.id)
        print("Name:",self.name)
        print("Department:",self.department)
        print("Age:",self.age)
        print("CGPA:",self.cgpa)
    @classmethod
    def from_String(cls,info):
        name,department,age,cgpa = info.split("-")
        obj = cls(name,department,age,cgpa) 
        return obj

s1 = Student("Samin", "CSE", 21, 3.91)
s1.get_details()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.get_details()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.get_details()
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.get_details() 
print()


print("Instance variables are declared in a class and class variables are declared with the static keyword in a class ")
print("Instance methods are the most common type of methods in Python classes and Class method can't access specific instance data.But class method can call other static methods.")
# Out:
# ID: 1
# Name: Samin
# Department: CSE
# Age: 21
# CGPA: 3.91
# -----------------------
# ID: 2
# Name: Fahim
# Department: ECE
# Age: 21
# CGPA: 3.85
# -----------------------
# ID: 3
# Name: Tahura
# Department: EEE
# Age: 22
# CGPA: 3.01
# -----------------------
# ID: 4
# Name: Sumaiya
# Department: BBA
# Age: 23
# CGPA: 3.96
#
# Instance variables are declared in a class and class variables are declared with the static keyword in a class
# Instance methods are the most common type of methods in Python classes and Class method can't access specific instance data.But class method can call other static methods.

# %%
#2
class Dates:
    def __init__(self,date):
        self.date = date
    @classmethod
    def toDashDate(cls,dates):
        day,month,year = dates.split('/')
        dates = day + "-" + month + "-" + year
        date = cls(dates)
        return date
    def getDate(self):
        return self.date


date1 = Dates("05-09-2020")
dateFromDB = "05/09/2020"
date2= Dates.toDashDate(dateFromDB)
if(date1.getDate() == date2.getDate()):
 print("Equal")
else:
 print("Unequal")

print("As we replace '/' to '-' in toDashDate class method, in the method both statements became same thats why conditional statement it prints Equal.")
# Out:
# Equal
# As we replace '/' to '-' in toDashDate class method, in the method both statements became same thats why conditional statement it prints Equal.

# %%
#3 
class Passenger:
    count = 0
    base_fare = 450

    def __init__(self, name, fare=0):
        self.name = name
        self.fare = fare
        Passenger.count += 1

    def set_bag_weight(self, weight):
        self.weight = weight

    def printDetail(self):
        print("Name:", self.name)
        if 20 < self.weight <= 50:
            self.fare = Passenger.base_fare + 50
            print("Bus fare:{}".format(self.fare))
        elif self.weight > 50:
            self.fare = Passenger.base_fare + 100
            print("Bus fare:{}".format(self.fare))
        else:
            self.fare = Passenger.base_fare
            print("Bus fare:{}".format(self.fare))


print("Total Passenger:", Passenger.count)
p1 = Passenger("Jack")
p1.set_bag_weight(90)
p2 = Passenger("Carol")
p2.set_bag_weight(10)
p3 = Passenger("Mike")
p3.set_bag_weight(25)
print("=========================")
p1.printDetail()
print("=========================")
p2.printDetail()
print("=========================")
p3.printDetail()
print("=========================")
print("Total Passenger:", Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name: Jack
# Bus fare:550
# ...
# Name: Carol
# Bus fare:450
# ...
# Name: Mike
# Bus fare:500
# ...
# Total Passenger: 3

# %%
#4
class Travel:
    count = 0
    def __init__(self,source,desti,time = 1):
        self.source = source
        self.desti = desti
        self.time = time
        Travel.count += 1
    def set_time(self,time):
        self.time = time
    def set_source(self, source):
        self.source = source
    def set_destination(self,desti):
        self.desti = desti
    def display_travel_info(self):
        self.time = str(self.time)
        print("Source:",self.source)
        print("Destinaton:",self.desti)
        self.time = self.time+":"+"00"
        return "Flight Time:{}".format(self.time)


print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source: Dhaka
# Destinaton: India
# Flight Time:1:00
# ...
# Source: Kuala Lampur
# Destinaton: Dhaka
# Flight Time:23:00
# ...
# Source: Dhaka
# Destinaton: Germany
# Flight Time:15:00
# ...
# Source: Malaysia
# Destinaton: Canada
# Flight Time:9:00
# ...
# No. of Traveller = 4

# %%
#5
class Fruit:
    fruitCount = 0
    def __init__(self,name,count):
        self.name = name
        self.count = count
        Fruit.fruitCount+=self.count
    @staticmethod
    def saySomethingGood():
        print("Fruits are good for health")
    @classmethod
    def resetcount(cls):
        Fruit.fruitCount = 0
        return Fruit.fruitCount
        

apples = Fruit("Apple", 3);
pears = Fruit("Pear", 4);
print(apples.name, apples.count)
print(pears.name,pears.count)
print("Total number of fruits", Fruit.fruitCount)
Fruit.saySomethingGood()
Fruit.resetcount()
print("Total number of fruits", Fruit.fruitCount)
# Out:
# Apple 3
# Pear 4
# Total number of fruits 7
# Fruits are good for health
# Total number of fruits 0

# %%
#6
class Cat:
    Number_of_cats = 0

    def __init__(self, color, doing):
        self.color = color

        self.doing = doing
        Cat.Number_of_cats += 1

    @classmethod
    def no_parameter(cls):
        color = "White"
        doing = "sitting"
        return cls(color, doing)

    @classmethod
    def first_parameter(cls, color):
        cls.color = color
        doing = "sitting"
        return cls(color, doing)

    @classmethod
    def second_parameter(cls, doing):
        color = "White"
        cls.doing = doing
        return cls(color, doing)

    def changeColor(self, color):
        self.color = color

    def printCat(self):
        print("{} cat is {}".format(self.color, self.doing))


print("Total number of cats:", Cat.Number_of_cats)
c1 = Cat.no_parameter()
c2 = Cat.first_parameter("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c5 = Cat.second_parameter("playing")
print("=======================")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c5.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
print("=======================")
print("Total number of cats:", Cat.Number_of_cats)
# Out:
# Total number of cats: 0
# ...
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# White cat is playing
# Blue cat is sitting
# Purple cat is jumping
# ...
# Total number of cats: 5

# %%
#7
import math


class Cylinder:
    radius = 5
    height = 18

    def __init__(self, radius, height):
        self.radius = radius
        self.height = height
        print("Default radius=", Cylinder.radius, "Default height=", Cylinder.height)
        Cylinder.radius = self.radius
        Cylinder.height = self.height
        print("Updated radius=", Cylinder.radius, "Updated height=", Cylinder.height)

    @classmethod
    def swap(cls, radius, height):
        return (cls(height, radius))

    @classmethod
    def changeFormat(cls, detail):
        radius, height = detail.split("-")
        radius = float(radius)
        height = float(height)
        return (cls(radius, height))

    @staticmethod
    def area(radius, height):
        area = (2 * math.pi * radius ** 2 + 2 * math.pi * radius * height)
        print("Area:", area)

    @staticmethod
    def volume(radius, height):
        volume = (math.pi * radius ** 2 * height)
        print("Volume:", volume)


c1 = Cylinder(0, 0)
Cylinder.area(c1.radius, c1.height)
Cylinder.volume(c1.radius, c1.height)
print("===============================")
c2 = Cylinder.swap(8, 3)
c2.area(c2.radius, c2.height)
c2.volume(c2.radius, c2.height)
print("===============================")
c3 = Cylinder.changeFormat("7-13")
c3.area(c3.radius, c3.height)
c3.volume(c3.radius, c3.height)
print("===============================")
Cylinder(0.3, 5.56).area(Cylinder.radius, Cylinder.height)
print("===============================")
Cylinder(3, 5).volume(Cylinder.radius, Cylinder.height)
# Out:
# Default radius= 5 Default height= 18
# Updated radius= 0 Updated height= 0
# Area: 0.0
# Volume: 0.0
# ...
# Default radius= 0 Default height= 0
# Updated radius= 3 Updated height= 8
# Area: 207.34511513692635
# Volume: 226.1946710584651
# ...
# Default radius= 3 Default height= 8
# Updated radius= 7.0 Updated height= 13.0
# Area: 879.645943005142
# Volume: 2001.1945203366981
# ...
# Default radius= 7.0 Default height= 13.0
# Updated radius= 0.3 Updated height= 5.56
# Area: 11.045839770021713
# ...
# Default radius= 0.3 Default height= 5.56
# Updated radius= 3 Updated height= 5
# Volume: 141.3716694115407
